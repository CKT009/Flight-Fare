# %%
import pandas as pd

# %%
df1 = pd.read_csv('transformed_train.csv')

# %%
df1.sample(10)
# Out:
#       Duration  Total_Stops    Price  Journey_Day  Journey_Month  Dep_hour  \
# 286   1.538403     0.738595  18260.0    -0.543261      -1.442778 -2.103603
# 5951       NaN          NaN      NaN          NaN            NaN       NaN
# 2158  2.166639     0.738595   6065.0     0.861757      -1.442778 -0.868090
# 852   1.047594     0.738595   9001.0     1.213011       1.127881 -0.456252
# 443  -0.837114    -0.954568   3841.0    -1.245769       0.270995  1.397019
# 130  -0.719320    -0.954568   7229.0     1.213011       0.270995  1.397019
# 4094 -0.817481    -0.954568   3873.0    -0.192006      -0.585891 -0.868090
# 3035  1.636565     0.738595   6883.0     0.861757      -1.442778 -0.456252
# 3114  0.890535     0.738595  10844.0     0.510503       0.270995 -0.456252
# 2684 -1.072702    -0.954568   5678.0    -1.245769       1.127881  1.808856
#
#       Dep_minute  Arrival_hour  Arrival_minute  Airline_Air India  ...  \
# ...

# %%
df1.isna().sum()
# Out:
# Duration                     1913
# Total_Stops                  1913
# Price                        1913
# Journey_Day                  1913
# Journey_Month                1913
# Dep_hour                     1913
# Dep_minute                   1913
# Arrival_hour                 1913
# Arrival_minute               1913
# Airline_Air India            1913
# Airline_GoAir                1913
# Airline_IndiGo               1913
# Airline_Jet Airways          1913
# Airline_Multiple carriers    1913
# Airline_Other                1913
# Airline_SpiceJet             1913
# Airline_Vistara              1913
# Source_Chennai               1913
# Source_Delhi                 1913
# Source_Kolkata               1913
# Source_Mumbai                1913
# Destination_Cochin           1913
# Destination_Delhi            1913
# Destination_Hyderabad        1913
# Destination_Kolkata          1913
# Destination_New Delhi        1913
# dtype: int64

# %%
len(df1)
# Out:
# 6656

# %%
df1['Airline'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\PWskills\INTERNSHIP\FLIGHT FARE\venv\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File d:\PWskills\INTERNSHIP\FLIGHT FARE\venv\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File d:\PWskills\INTERNSHIP\FLIGHT FARE\venv\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Airline'
#
# The above exception was the direct cause of the following exception:
#
# ...
